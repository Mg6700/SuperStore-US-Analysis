# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_excel("P6-SuperStoreUS-2015.xlsx")

# %%
dataset.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   22823            Low      0.07        4.84           0.71         1418
# 1   22824            Low      0.04     2036.48          14.70         1425
#
#      Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0  Rebecca Lindsey     Regular Air   Small Business  Office Supplies  ...
# 1    Gregory Crane  Delivery Truck   Small Business       Technology  ...
#
#     Region State or Province          City  Postal Code Order Date  Ship Date  \
# 0  Central           Indiana        Kokomo        46901 2015-01-01 2015-01-03
# 1     West          Colorado  Fort Collins        80525 2015-01-01 2015-01-06
#
#       Profit Quantity ordered new    Sales Order ID
# 0    25.2402                    8    36.58    90539
# 1 -4793.0040                    1  2013.67    89450
#
# [2 rows x 25 columns]

# %%
dataset.isnull().sum()
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     16
# Country                  0
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %%
dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(), inplace=True)
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_4432\2786864021.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Product Base Margin"].fillna(dataset["Product Base Margin"].mean(), inplace=True)

# %%
dataset["Order Priority"].value_counts()
# Out:
# Order Priority
# Low              398
# Not Specified    396
# High             391
# Critical         390
# Medium           376
# Critical           1
# Name: count, dtype: int64

# %%
dataset["Order Priority"].unique()
# Out:
# array(['Low', 'Critical', 'Not Specified', 'High', 'Medium', 'Critical '],
#       dtype=object)

# %%
dataset["Order Priority"].replace("Critical ", "Critical", inplace=True)
# Out:
# C:\Users\Mayur\AppData\Local\Temp\ipykernel_4432\623612887.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Order Priority"].replace("Critical ", "Critical", inplace=True)

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Order Priority", data=dataset)
plt.title("Count of Order Priority")
plt.savefig("Count of Order Priority.jpg")
plt.show()

# %%
dataset["Ship Mode"].value_counts()
# Out:
# Ship Mode
# Regular Air       1437
# Delivery Truck     275
# Express Air        240
# Name: count, dtype: int64

# %%
x = dataset["Ship Mode"].value_counts().index
y = dataset["Ship Mode"].value_counts().values

# %%
plt.figure(figsize=(6,5))
plt.pie(y, labels=x, startangle=201, autopct="%0.1f%%")
plt.legend(loc= 1)
plt.title("Ship Mode %")
plt.savefig("Ship Mode %.jpg")
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot(x="Ship Mode",data=dataset, hue="Product Category")
plt.title("Ship Mode Based on Product Category")
plt.savefig("Ship Mode Based on Product Category.jpg")
plt.show()

# %%
plt.figure(figsize=(6,5))
sns.countplot(x="Customer Segment",data=dataset)
plt.title("Customer Segment")
plt.savefig("Customer Segment.jpg")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Product Category",data=dataset[dataset["Product Category"]=="Office Supplies"], hue="Product Sub-Category")
plt.title("Office Supplies Sub-Category")
plt.savefig("Office Supplies Sub-Category.jpg")
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.countplot(x="Product Category",data=dataset[dataset["Product Category"]=="Furniture"], hue="Product Sub-Category")
plt.title("Furniture Sub-Category")
plt.savefig("Furniture Sub-Category.jpg")
plt.show()

# %%
plt.figure(figsize=(7,6))
sns.countplot(x="Product Category",data=dataset[dataset["Product Category"]=="Technology"], hue="Product Sub-Category")
plt.title("Technology Sub-Category")
plt.savefig("Technology Sub-Category.jpg")
plt.show()

# %%
dataset["Order Month"] = dataset["Order Date"].dt.month

# %%
dataset["Order Month"].value_counts()
# Out:
# Order Month
# 1    370
# 3    328
# 4    321
# 2    314
# 5    313
# 6    306
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.countplot(x="Order Month",data=dataset)
plt.title("Orders Based on Months")
plt.savefig("Orders Based on Months.jpg")
plt.show()

# %%
sns.barplot(x="Product Category", y="Profit",data=dataset, estimator="sum")
plt.title("Profit Based on Product Category")
plt.savefig("Profit Based on Product Category.jpg")
plt.show()

# %%
sns.barplot(x="Product Category", y="Product Base Margin",data=dataset, estimator="sum")
plt.title("Product Base Margin Based on Product Category")
plt.savefig("Product Base Margin Based on Product Category.jpg")
plt.show()

# %%
sns.countplot(x="Product Category",data=dataset)
plt.title("Orders Based on Product Category")
plt.savefig("Orders Based on Product Category.jpg")
plt.show()
